# %% [markdown]
# <a href="https://colab.research.google.com/github/ikwabia/Analysing_mydata/blob/main/Purchase_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3fd25879-a8ab-4657-b986-687db0d09377" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3fd25879-a8ab-4657-b986-687db0d09377">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data =pd.read_csv('/content/purchases.csv')

# %% [markdown]
# # New Section

# %%
data
# Out:
#           DATE        DAY         SHOP  AMOUNT(Euro) MEANS OF PAYMENT
# 0   12.08.2023   Saturday     Kaufland         57.62             GELD
# 1   12.08.2023   Saturday       Amazon        187.11            KARTE
# 2   18.08.2023     Friday   Asia Might         57.15      KARTE &GELD
# 3   14.08.2023     Monday    Woolworth         10.00             GELD
# 4   14.08.2023     Monday    Deichmann         24.99            KARTE
# 5   14.08.2024     Monday          H&M         58.92            KARTE
# 6   14.08.2025     Monday         Tedi          6.55             GELD
# 7   23.08.2023  Wednesday      Rossman          4.27             GELD
# 8   26.08.2023   Saturday     Kaufland         33.96             GELD
# 9   28.08.2023     Monday         Temu         10.24            KARTE
# 10  30.08.2023  Wednesday     Kaufland          9.98             GELD
# 11  09.09.2023   Saturday     Kaufland         27.35            KARTE
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(review for review in data['SHOP'])
wordcloud = WordCloud(width=1000, height=400, background_color='white').generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(review for review in data['DAY'])
wordcloud = WordCloud(width=1000, height=400, background_color='white').generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
data.describe().transpose()
# Out:
#               count       mean        std   min    25%     50%      75%  \
# AMOUNT(Euro)   52.0  27.564231  30.104255  1.64  7.715  18.825  41.6775
#
#                  max
# AMOUNT(Euro)  187.11

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATE              52 non-null     object
#  1   DAY               52 non-null     object
#  2   SHOP              52 non-null     object
#  3   AMOUNT(Euro)      52 non-null     float64
#  4   MEANS OF PAYMENT  52 non-null     object
#  5   CEDIS             52 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 2.6+ KB

# %%
data.shape
# Out:
# (52, 6)

# %%
data.head(3)
# Out:
#          DATE       DAY        SHOP  AMOUNT(Euro) MEANS OF PAYMENT
# 0  12.08.2023  Saturday    Kaufland         57.62             GELD
# 1  12.08.2023  Saturday      Amazon        187.11            KARTE
# 2  18.08.2023    Friday  Asia Might         57.15      KARTE &GELD

# %%
data['AMOUNT(Euro)'].sum()
# Out:
# 1433.3400000000001

# %% [markdown]
# The total payment till date is 1433.34 Euros, with an average expenditure of 27.56 Euros.

# %%
data['CEDIS']= data['AMOUNT(Euro)']*12.70 #checking the payment made in cedis(homecountry currency)

# %%
data
# Out:
#           DATE        DAY         SHOP  AMOUNT(Euro) MEANS OF PAYMENT  \
# 0   12.08.2023   Saturday     Kaufland         57.62             GELD
# 1   12.08.2023   Saturday       Amazon        187.11            KARTE
# 2   18.08.2023     Friday   Asia Might         57.15      KARTE &GELD
# 3   14.08.2023     Monday    Woolworth         10.00             GELD
# 4   14.08.2023     Monday    Deichmann         24.99            KARTE
# 5   14.08.2024     Monday          H&M         58.92            KARTE
# 6   14.08.2025     Monday         Tedi          6.55             GELD
# 7   23.08.2023  Wednesday      Rossman          4.27             GELD
# 8   26.08.2023   Saturday     Kaufland         33.96             GELD
# 9   28.08.2023     Monday         Temu         10.24            KARTE
# 10  30.08.2023  Wednesday     Kaufland          9.98             GELD
# 11  09.09.2023   Saturday     Kaufland         27.35            KARTE
# ...

# %%
#checking how much i paid above the average
data[data['AMOUNT(Euro)']>27.564231]
# Out:
#           DATE       DAY         SHOP  AMOUNT(Euro) MEANS OF PAYMENT     CEDIS
# 0   12.08.2023  Saturday     Kaufland         57.62             GELD   731.774
# 1   12.08.2023  Saturday       Amazon        187.11            KARTE  2376.297
# 2   18.08.2023    Friday   Asia Might         57.15      KARTE &GELD   725.805
# 5   14.08.2024    Monday          H&M         58.92            KARTE   748.284
# 8   26.08.2023  Saturday     Kaufland         33.96             GELD   431.292
# 12  29.09.2023    Friday     Kaufland         56.08            KARTE   712.216
# 13  16.09.2023  Saturday     Kaufland         59.03            KARTE   749.681
# 17  18.09.2023    Monday  Lothar Zech         46.17            KARTE   586.359
# 22  21.09.2023  Thursday   Asia Might         51.10             GELD   648.970
# 24    06.10.23    Friday   Asia Might         51.70            KARTE   656.590
# 25    14.10.23  Saturday     Kaufland         40.18            KARTE   510.286
# ...

# %%
a = data[data['AMOUNT(Euro)']>27.564231]

# %%
a.describe()
# Out:
#        AMOUNT(Euro)        CEDIS
# count     19.000000    19.000000
# mean      55.545789   705.431526
# std       33.929344   430.902672
# min       30.640000   389.128000
# 25%       38.315000   486.600500
# 50%       51.100000   648.970000
# 75%       57.385000   728.789500
# max      187.110000  2376.297000

# %%
#checking how much i paid up to the average
data[data['AMOUNT(Euro)']<27.564231]
# Out:
#           DATE        DAY       SHOP  AMOUNT(Euro) MEANS OF PAYMENT    CEDIS
# 3   14.08.2023     Monday  Woolworth         10.00             GELD  127.000
# 4   14.08.2023     Monday  Deichmann         24.99            KARTE  317.373
# 6   14.08.2025     Monday       Tedi          6.55             GELD   83.185
# 7   23.08.2023  Wednesday    Rossman          4.27             GELD   54.229
# 9   28.08.2023     Monday       Temu         10.24            KARTE  130.048
# 10  30.08.2023  Wednesday   Kaufland          9.98             GELD  126.746
# 11  09.09.2023   Saturday   Kaufland         27.35            KARTE  347.345
# 14  13.09.2023  Wednesday      Netto          9.83            KARTE  124.841
# 15  20.09.2023  Wednesday      Netto          7.01            KARTE   89.027
# 16  18.09.2023     Monday        H&M          7.98             GELD  101.346
# 18  21.09.2023   Thursday      Netto          2.58             GELD   32.766
# ...

# %%
data.sort_values(by=['AMOUNT(Euro)'])
# Out:
#           DATE        DAY         SHOP  AMOUNT(Euro) MEANS OF PAYMENT  \
# 19  27.09.2023  Wednesday        Netto          1.64             GELD
# 35    24.10.23    Tuesday      Rossman          1.98            KARTE
# 51    08.12.23     Friday      Rossman          2.58             GELD
# 32    25.10.23  Wednesday      Rossman          2.58            KARTE
# 18  21.09.2023   Thursday        Netto          2.58             GELD
# 27    19.10.23   Thursday         LIdl          2.59             GELD
# 7   23.08.2023  Wednesday      Rossman          4.27             GELD
# 38    02.11.23   Thursday         Lidl          4.57            KARTE
# 41    20.11.23     Monday        Netto          4.65             GELD
# 6   14.08.2025     Monday         Tedi          6.55             GELD
# 44    25.11.23   Saturday           DM          6.70             GELD
# 21  25.09.2023     Monday           DM          6.90             GELD
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('SHOP').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.gca().set_facecolor('lightgray')
plt.title("RATE OF VISIT")
# Out:
# Text(0.5, 1.0, 'RATE OF VISIT')

# %% [markdown]
# **The above graph have shown how often purchases were made within different shops.The graph shows Netto followed by Kaufland and Asia Might with the highest visitation.**

# %%
M = data[data['MEANS OF PAYMENT']=='GELD']
K = data[data['MEANS OF PAYMENT']=='KARTE']

# %%
M.describe().transpose()
# Out:
#               count      mean         std     min      25%      50%  \
# AMOUNT(Euro)   24.0   17.1050   16.548074   1.640   6.0750    9.990
# CEDIS          24.0  217.2335  210.160544  20.828  77.1525  126.873
#
#                     75%      max
# AMOUNT(Euro)   25.67250   57.620
# CEDIS         326.04075  731.774

# %%
M.sum() #checked total amount of payment by card. 410.52 Euro
# Out:
# DATE                12.08.202314.08.202314.08.202523.08.202326.08....
# DAY                 SaturdayMondayMondayWednesdaySaturdayWednesday...
# SHOP                KauflandWoolworthTediRossmanKauflandKauflandH&...
# AMOUNT(Euro)                                                   410.52
# MEANS OF PAYMENT    GELDGELDGELDGELDGELDGELDGELDGELDGELDGELDGELDGE...
# CEDIS                                                        5213.604
# dtype: object

# %%
K.describe().transpose()
# Out:
#               count        mean         std     min      25%      50%  \
# AMOUNT(Euro)   27.0   35.765556   36.482032   1.980   11.070   25.230
# CEDIS          27.0  454.222556  463.321811  25.146  140.589  320.421
#
#                   75%       max
# AMOUNT(Euro)   50.720   187.110
# CEDIS         644.144  2376.297

# %%
K.sum() #checked total amount of payment by card. 965.67 Euro
# Out:
# DATE                12.08.202314.08.202314.08.202428.08.202309.09....
# DAY                 SaturdayMondayMondayMondaySaturdayFridaySaturd...
# SHOP                AmazonDeichmannH&MTemuKauflandKauflandKaufland...
# AMOUNT(Euro)                                                   965.67
# MEANS OF PAYMENT    KARTEKARTEKARTEKARTEKARTEKARTEKARTEKARTEKARTEK...
# CEDIS                                                       12264.009
# dtype: object

# %%
data[data['DAY']== 'Saturday']
# Out:
#           DATE       DAY         SHOP  AMOUNT(Euro) MEANS OF PAYMENT     CEDIS
# 0   12.08.2023  Saturday     Kaufland         57.62             GELD   731.774
# 1   12.08.2023  Saturday       Amazon        187.11            KARTE  2376.297
# 8   26.08.2023  Saturday     Kaufland         33.96             GELD   431.292
# 11  09.09.2023  Saturday     Kaufland         27.35            KARTE   347.345
# 13  16.09.2023  Saturday     Kaufland         59.03            KARTE   749.681
# 23    07.10.23  Saturday     Kaufland         18.01             GELD   228.727
# 25    14.10.23  Saturday     Kaufland         40.18            KARTE   510.286
# 29    21.10.23  Saturday  Lothar Zech         49.74            KARTE   631.698
# 31    21.10.23  Saturday        Netto         10.85             GELD   137.795
# 33    28.10.23  Saturday        Netto         10.10            KARTE   128.270
# 34    28.10.23  Saturday     Kaufland         23.77             GELD   301.879
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('DAY').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.title("SHOPPING DAYS")
plt.gca().spines[['top', 'right']].set_visible(False)
plt.gca().set_facecolor('lightgray')
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('MEANS OF PAYMENT').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.title("MODE OF PAYMENT")
plt.gca().spines[['top', 'right']].set_visible(False)
plt.gca().set_facecolor('lightgray')
plt.show()

# %%
data.sort_values(['AMOUNT(Euro)','DATE'])

# %%
data['AMOUNT(Euro)'].max()
# Out:
# 187.11

# %%
data['AMOUNT(Euro)'].min()
# Out:
# 1.64

# %%
data['SHOP'].value_counts()
# Out:
# Netto          14
# Kaufland       12
# Asia Might      6
# Rossman         4
# H&M             3
# Lothar Zech     2
# DM              2
# Amazon          1
# Woolworth       1
# Deichmann       1
# Tedi            1
# Temu            1
# LIdl            1
# KFC             1
# Lidl            1
# Penny           1
# Name: SHOP, dtype: int64

# %%
data['DAY'].value_counts() #add to your graphs in a form of table.
# Out:
# Saturday     19
# Monday       12
# Friday       10
# Wednesday     6
# Thursday      4
# Tuesday       1
# Name: DAY, dtype: int64

# %%
data['MEANS OF PAYMENT'].value_counts() #add to your graphs in a form of table.
# Out:
# KARTE          27
# GELD           24
# KARTE &GELD     1
# Name: MEANS OF PAYMENT, dtype: int64

# %% [markdown]
# **I checked the average amount spent in every shop.**

# %%
data.groupby('SHOP').mean()
# Out:
# <ipython-input-39-449e563eb3da>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('SHOP').mean()
#              AMOUNT(Euro)        CEDIS
# SHOP
# Amazon         187.110000  2376.297000
# Asia Might      53.400000   678.180000
# DM               6.800000    86.360000
# Deichmann       24.990000   317.373000
# H&M             30.626667   388.958667
# KFC             16.780000   213.106000
# Kaufland        36.680000   465.836000
# LIdl             2.590000    32.893000
# Lidl             4.570000    58.039000
# Lothar Zech     47.955000   609.028500
# Netto           12.785714   162.378571
# Penny           18.150000   230.505000
# Rossman          2.852500    36.226750
# Tedi             6.550000    83.185000
# Temu            10.240000   130.048000
# ...

# %%
data.groupby('SHOP').sum()
# Out:
# <ipython-input-14-ca77c341ff38>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('SHOP').sum()
#              AMOUNT(Euro)
# SHOP
# Amazon             187.11
# Asia Might         320.40
# DM                  13.60
# Deichmann           24.99
# H&M                 91.88
# KFC                 16.78
# Kaufland           440.16
# LIdl                 2.59
# Lidl                 4.57
# Lothar Zech         95.91
# Netto              179.00
# Penny               18.15
# Rossman             11.41
# Tedi                 6.55
# Temu                10.24
# Woolworth           10.00

# %% [markdown]
# Though many purchases were made at Netto, Kaufland had the highest amount of payment for purchases made.

# %%
data[data['AMOUNT(Euro)'].between(20,70,inclusive=True)]
